# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client(api_key='API_KEY')

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="What is the deepest crater on the moon?"
)
print(response.text)
# Out:
# The deepest crater on the Moon is generally considered to be **Newton**.
#
# It's located near the Moon's South Pole. Its floor lies approximately **6,000 meters (6 kilometers or nearly 3.7 miles)** below its rim. This extreme depth means parts of its floor are permanently shadowed, making it a prime candidate for holding water ice.
